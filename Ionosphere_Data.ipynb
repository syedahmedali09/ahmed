# %%
import pandas as pd
data_frame=pd.read_csv("/content/ionosphere_data.csv")
data_frame
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 0           1         0   0.99539  ...    0.18641   -0.45300      g
# 1           1         0   1.00000  ...   -0.13738   -0.02447      b
# 2           1         0   1.00000  ...    0.56045   -0.38238      g
# 3           1         0   1.00000  ...   -0.32382    1.00000      b
# 4           1         0   1.00000  ...   -0.04608   -0.65697      g
# ..        ...       ...       ...  ...        ...        ...    ...
# 346         1         0   0.83508  ...    0.90546   -0.04307      g
# 347         1         0   0.95113  ...    0.91483    0.04712      g
# 348         1         0   0.94701  ...    0.92697   -0.00577      g
# 349         1         0   0.90608  ...    0.87403   -0.16243      g
# 350         1         0   0.84710  ...    0.85764   -0.06151      g
#
# [351 rows x 35 columns]

# %%
data_frame.isnull().sum()
# Out:
# feature1     0
# feature2     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %%
from sklearn.utils import shuffle

finall_df = shuffle(data_frame)

# %%
from sklearn.preprocessing import  LabelEncoder
finall_df["label"]=LabelEncoder().fit_transform(finall_df['label'])

# %%
finall_df
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 22          1         0   0.96071  ...    0.52099   -0.00182      1
# 34          1         0   1.00000  ...    1.00000   -0.57758      1
# 5           1         0   0.02337  ...   -0.00039    0.12011      0
# 290         1         0   0.47337  ...    0.34615   -0.00296      1
# 89          1         0   0.41932  ...   -0.00526   -0.06314      0
# ..        ...       ...       ...  ...        ...        ...    ...
# 305         1         0   0.52542  ...    0.76271   -0.10169      1
# 309         1         0   0.83789  ...    0.48319   -0.24313      1
# 293         1         0   0.87772  ...    0.79076   -0.00543      1
# 228         0         0   1.00000  ...    1.00000    1.00000      0
# 254         1         0   0.32834  ...    0.12197    0.20468      1
#
# [351 rows x 35 columns]

# %%
finall_df.reset_index(inplace=True, drop=True)

# %%
finall_df
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 0           1         0   0.96071  ...    0.52099   -0.00182      1
# 1           1         0   1.00000  ...    1.00000   -0.57758      1
# 2           1         0   0.02337  ...   -0.00039    0.12011      0
# 3           1         0   0.47337  ...    0.34615   -0.00296      1
# 4           1         0   0.41932  ...   -0.00526   -0.06314      0
# ..        ...       ...       ...  ...        ...        ...    ...
# 346         1         0   0.52542  ...    0.76271   -0.10169      1
# 347         1         0   0.83789  ...    0.48319   -0.24313      1
# 348         1         0   0.87772  ...    0.79076   -0.00543      1
# 349         0         0   1.00000  ...    1.00000    1.00000      0
# 350         1         0   0.32834  ...    0.12197    0.20468      1
#
# [351 rows x 35 columns]

# %%
train_x = finall_df.iloc[0:210, 0:-1]
train_y = finall_df.iloc[0:210, -1]

test_x = finall_df.iloc[210:, 0:-1]
test_y = finall_df.iloc[210:, -1]

# %%
mean = train_data.mean()
std = train_data.std()

train_x-=mean
train_x/=std

test_x-=mean
test_x/=std

# %%
train_x
# Out:
#      feature1  feature2  feature3  ...  feature32  feature33  feature34
# 0     0.34987       NaN  0.626558  ...   0.009955   0.276473  -0.084765
# 1     0.34987       NaN  0.710349  ...   1.035800   1.147768  -1.303003
# 2     0.34987       NaN -1.372437  ...   0.010243  -0.671891   0.173224
# 3     0.34987       NaN -0.412756  ...  -0.268321  -0.041552  -0.087177
# 4     0.34987       NaN -0.528024  ...  -0.133180  -0.680749  -0.214511
# ..        ...       ...       ...  ...        ...        ...        ...
# 205   0.34987       NaN -2.821813  ...   0.010243  -0.671181   0.117449
# 206   0.34987       NaN -1.206135  ...   0.010243  -0.671181  -0.080914
# 207   0.34987       NaN  0.710349  ...   0.568908   0.556482   0.560048
# 208   0.34987       NaN  0.710349  ...   1.057898  -1.449965   0.861370
# 209   0.34987       NaN  0.710349  ...  -0.976057  -0.337350  -1.066976
#
# [210 rows x 34 columns]

# %%
finall_df
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 0           1         0   0.96071  ...    0.52099   -0.00182      1
# 1           1         0   1.00000  ...    1.00000   -0.57758      1
# 2           1         0   0.02337  ...   -0.00039    0.12011      0
# 3           1         0   0.47337  ...    0.34615   -0.00296      1
# 4           1         0   0.41932  ...   -0.00526   -0.06314      0
# ..        ...       ...       ...  ...        ...        ...    ...
# 346         1         0   0.52542  ...    0.76271   -0.10169      1
# 347         1         0   0.83789  ...    0.48319   -0.24313      1
# 348         1         0   0.87772  ...    0.79076   -0.00543      1
# 349         0         0   1.00000  ...    1.00000    1.00000      0
# 350         1         0   0.32834  ...    0.12197    0.20468      1
#
# [351 rows x 35 columns]

# %%
test_x.drop('feature2', inplace=True, axis=1)

# %%
train_x.drop('feature2', inplace=True, axis=1)

# %%
mean = train_data.mean()
std = train_data.std()

train_x-=mean
train_x/=std

test_x-=mean
test_x/=std

# %%
from keras import models, layers

model = models.Sequential()

model.add(layers.Dense(16, input_shape=(train_x.shape[1],), activation='relu' ))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(6, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_x,train_y ,validation_split=0.2,epochs=70)
# Out:
# Epoch 1/70
# 6/6 [==============================] - 1s 50ms/step - loss: 0.6999 - accuracy: 0.4179 - val_loss: 0.7120 - val_accuracy: 0.4524
# Epoch 2/70
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6931 - accuracy: 0.4400 - val_loss: 0.6964 - val_accuracy: 0.5952
# Epoch 3/70
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6692 - accuracy: 0.5733 - val_loss: 0.6843 - val_accuracy: 0.6429
# Epoch 4/70
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6659 - accuracy: 0.5776 - val_loss: 0.6737 - val_accuracy: 0.6667
# Epoch 5/70
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6427 - accuracy: 0.6533 - val_loss: 0.6652 - val_accuracy: 0.6667
# Epoch 6/70
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6316 - accuracy: 0.7181 - val_loss: 0.6562 - val_accuracy: 0.6905
# Epoch 7/70
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6360 - accuracy: 0.7016 - val_loss: 0.6480 - val_accuracy: 0.7857
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
loss = history.history['accuracy']
val_loss = history.history['val_accuracy']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, val_loss, 'y', label='Validation acc', linewidth=10)
plt.plot(epochs, loss, 'g', label='Training acc', linewidth=4)
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('acc')
plt.legend()
plt.show()

# %%
model.evaluate(test_x,test_y)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3673 - accuracy: 0.9078
# [0.36734214425086975, 0.9078013896942139]

# %%
model.predict(test_x)
# Out:
# array([[1.6614255e-01],
#        [9.3280089e-01],
#        [9.9510169e-01],
#        [9.6899849e-01],
#        [9.8399276e-01],
#        [9.8958987e-01],
#        [9.8387516e-01],
#        [1.6380328e-01],
#        [9.8842293e-01],
#        [1.3018760e-01],
#        [3.3517718e-01],
#        [6.8383062e-01],
#        [9.7106045e-01],
#        [9.8000050e-01],
#        [9.6142125e-01],
#        [1.5407801e-04],
#        [3.3819860e-01],
#        [7.7433914e-01],
#        [9.7564805e-01],
#        [5.7833791e-03],
#        [1.7577410e-04],
#        [7.6331109e-01],
#        [9.9674761e-01],
#        [9.9888819e-01],
#        [2.2547960e-01],
#        [9.6207798e-01],
#        [9.9468589e-01],
#        [9.6292096e-01],
#        [9.9995613e-01],
#        [9.8405761e-01],
#        [1.9063950e-03],
#        [9.9174106e-01],
#        [9.9803007e-01],
#        [6.2621981e-01],
#        [6.2999314e-01],
#        [7.8590798e-01],
#        [7.4398774e-01],
#        [9.9890888e-01],
# ...
